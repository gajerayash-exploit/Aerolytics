# %%
# !pip install ultralytics opencv-python

from ultralytics import YOLO

# Load the AI Engine
print("Loading AI Engine...")
model = YOLO('yolov8n.pt')

# Train the model on your solar panel dataset
print("Starting Training Process...")
results = model.train(
    data='data.yaml',    
    epochs=15,           
    imgsz=640,           
    plots=True           
)

print("Training Complete!")
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Creating new Ultralytics Settings v0.0.8 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\dell\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# Loading AI Engine...
# ...
# Starting Training Process...
# Ultralytics 8.4.143  Python-3.13.9 torch-2.14.0+cpu CPU (Intel Core i5-8350U 1.70GHz)
# ...

# %%
from ultralytics import YOLO

# 1. Load YOUR newly trained model (not the base model anymore!)
print("Loading Custom Aerolytics AI...")
model = YOLO(r'runs/detect/train/weights/best.pt')

# 2. Run the AI on your validation images to see if it catches the defects
print("Running AI scan on test images...")
results = model.predict(source='valid/images', save=True)

print("Scan Complete! Check your folders for the AI output.")
# Out:
# Loading Custom Aerolytics AI...
# Running AI scan on test images...
#
# image 1/310 D:\DaaS-Frolic\daas_backend\valid\images\1675443763040_jpg.rf.bd46251cbb2c2da017a05d338f79ddde.jpg: 640x640 1 normal, 132.3ms
# image 2/310 D:\DaaS-Frolic\daas_backend\valid\images\1675443763040_jpg.rf.e6a19e899fa39ae622d40e53206f0425.jpg: 640x640 1 normal, 79.2ms
# image 3/310 D:\DaaS-Frolic\daas_backend\valid\images\1675443763066_jpg.rf.5461f619899cc2790ae37229037b2922.jpg: 640x640 1 normal, 82.7ms
# image 4/310 D:\DaaS-Frolic\daas_backend\valid\images\1675443763093_jpg.rf.6bdeb48ef6ec63cfcc1278c2654f44d7.jpg: 640x640 1 normal, 81.9ms
# image 5/310 D:\DaaS-Frolic\daas_backend\valid\images\1677069178267_jpg.rf.0415c7d7d79f6548fe1cc5cda34be020.jpg: 640x640 1 cover, 1 normal, 124.4ms
# image 6/310 D:\DaaS-Frolic\daas_backend\valid\images\1677069178292_jpg.rf.245bb62c23af86bda80f19c575f908ca.jpg: 640x640 1 cover, 1 normal, 92.7ms
# ...
